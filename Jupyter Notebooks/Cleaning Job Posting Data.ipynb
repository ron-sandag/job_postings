# %%
import pandas as pd
import re

# %%
# Combine the new and cumulative data sets
cumulative_job_posting_df = pd.read_csv("../Data/Job_posting_data_cumulative.csv")
new_job_posting_df = pd.read_csv("../Data/Job_posting_data_current.csv")

total_job_posting_df = pd.concat([cumulative_job_posting_df, new_job_posting_df])

# Show the new cumulative data set
print(total_job_posting_df)
# Out:
#                                              Job Title  \
# 0                           route sales representative
# 1                                ultrasound technician
# 2                     optometric ophthalmic technician
# 3                                           controller
# 4                                      account manager
# ..                                                 ...
# 850                                  Warehouse Manager
# 851                                    Delivery Driver
# 852  Executive Assistant/Administrative Specialist ...
# 853                       NUTRITIONIST-HEALTH EDUCATOR
# 854        Access Control Officer (Part-Time) - Savina
#
#                               Company Name  \
# 0                  frito lay north america
# 1                    proximity diagnostics
# 2                 imperial beach optometry
# 3                                 filtrous
# 4                            aya corporate
# ..                                     ...
# 850  Behind the Scenes Catering and Events
# 851                       Le Parfait Paris
# 852                          Woongjin, Inc
# 853     Family Health Centers of San Diego
# 854             Action Property Management
#
#                                               Location  Remote  \
# 0    San Diego, CA 92123 \n(Kearny Mesa area)\n+1 l...   False
# 1                                        San Diego, CA   False
# 2                Imperial Beach, CA 91932\n+1 location   False
# 3                                      Poway, CA 92064   False
# 4                         San Diego, CA\n+18 locations   False
# ..                                                 ...     ...
# 850                                      San Diego, CA   False
# 851                                San Diego, CA 92120   False
# 852                                      San Diego, CA   False
# 853  San Diego, CA 92102\n(Mt. Hope area)\n+1 location   False
# 854                  San Diego, CA 92101\n+3 locations   False
#
#                          Salary  Full Time  Part Time Date Posted
# 0                 $1,179 a week       True      False    1/7/2022
# 1        $1,800 - $3,200 a week      False       True    1/7/2022
# 2             $10 - $18 an hour       True      False    1/7/2022
# 3    $100,000 - $150,000 a year       True      False    1/7/2022
# 4    $100,000 - $175,000 a year      False      False    1/7/2022
# ..                          ...        ...        ...         ...
# 850                         NaN       True      False  2022-01-28
# 851           $18 - $20 an hour      False       True  2022-01-28
# 852                         NaN       True      False  2022-01-28
# 853                         NaN      False       True  2022-01-28
# 854                 $19 an hour      False       True  2022-01-28
#
# [8124 rows x 8 columns]

# %%
# Drop rows with blank "job title" or "company name"

total_job_posting_df.dropna(subset=['Job Title', 'Company Name'], inplace=True)

# %%
# Format the "job title" and "company name" columns
total_job_posting_df['Job Title'] = total_job_posting_df['Job Title'].str.replace('/', ' ')
total_job_posting_df['Job Title'] = total_job_posting_df['Job Title'].str.replace('-', ' ')
total_job_posting_df['Job Title'] = total_job_posting_df['Job Title'].str.lower()

total_job_posting_df['Company Name'] = total_job_posting_df['Company Name'].str.replace('/', ' ')
total_job_posting_df['Company Name'] = total_job_posting_df['Company Name'].str.replace('-', ' ')
total_job_posting_df['Company Name'] = total_job_posting_df['Company Name'].str.lower()
print(total_job_posting_df)
# Out:
#                                              Job Title  \
# 0                           route sales representative
# 1                                ultrasound technician
# 2                     optometric ophthalmic technician
# 3                                           controller
# 4                                      account manager
# ..                                                 ...
# 850                                  warehouse manager
# 851                                    delivery driver
# 852  executive assistant administrative specialist ...
# 853                       nutritionist health educator
# 854        access control officer (part time)   savina
#
#                               Company Name  \
# 0                  frito lay north america
# 1                    proximity diagnostics
# 2                 imperial beach optometry
# 3                                 filtrous
# 4                            aya corporate
# ..                                     ...
# 850  behind the scenes catering and events
# 851                       le parfait paris
# 852                          woongjin, inc
# 853     family health centers of san diego
# 854             action property management
#
#                                               Location  Remote  \
# 0    San Diego, CA 92123 \n(Kearny Mesa area)\n+1 l...   False
# 1                                        San Diego, CA   False
# 2                Imperial Beach, CA 91932\n+1 location   False
# 3                                      Poway, CA 92064   False
# 4                         San Diego, CA\n+18 locations   False
# ..                                                 ...     ...
# 850                                      San Diego, CA   False
# 851                                San Diego, CA 92120   False
# 852                                      San Diego, CA   False
# 853  San Diego, CA 92102\n(Mt. Hope area)\n+1 location   False
# 854                  San Diego, CA 92101\n+3 locations   False
#
#                          Salary  Full Time  Part Time Date Posted
# 0                 $1,179 a week       True      False    1/7/2022
# 1        $1,800 - $3,200 a week      False       True    1/7/2022
# 2             $10 - $18 an hour       True      False    1/7/2022
# 3    $100,000 - $150,000 a year       True      False    1/7/2022
# 4    $100,000 - $175,000 a year      False      False    1/7/2022
# ..                          ...        ...        ...         ...
# 850                         NaN       True      False  2022-01-28
# 851           $18 - $20 an hour      False       True  2022-01-28
# 852                         NaN       True      False  2022-01-28
# 853                         NaN      False       True  2022-01-28
# 854                 $19 an hour      False       True  2022-01-28
#
# [8124 rows x 8 columns]

# %% [markdown]
# # Here, we remove the duplicate rows, (ignoring the "Date Posted" b/c the same job can be posted on multiple days)

# %%
#Find duplicate job postings
total_job_posting_df.loc[total_job_posting_df.duplicated(subset=['Job Title', 'Company Name', 'Location', 'Remote', 'Salary'])]
# Out:
#                                               Job Title  \
# 1592                                            cashier
# 1982  utility and maintenance specialist i ii  syste...
# 2023                                       meter reader
# 2049                                             joiner
# 2292                             inspection tenchnician
# ...                                                 ...
# 840                   valet attendant $$$$$$$$$$$$ tips
# 841          speech language pathology assistant (slpa)
# 843   diagnostic imaging technical lead virtual hiri...
# 847               customer service rep self storage mgr
# 852   executive assistant administrative specialist ...
#
#                        Company Name                         Location  Remote  \
# 1592         the cheesecake factory              San Diego, CA 92108   False
# 1982              city of encinitas              Encinitas, CA 92024   False
# 2023                 american water               Imperial Beach, CA   False
# 2049                        aerotek                    San Diego, CA   False
# 2292             la solar group inc                    San Diego, CA   False
# ...                             ...                              ...     ...
# 840   ace parking management   sara       Coronado, CA\n+8 locations   False
# 841       speech improvement center    Chula Vista, CA\n+2 locations   False
# 843             inova health system                    United States   False
# 847                  public storage  National City, CA\n+7 locations   False
# 852                   woongjin, inc                    San Diego, CA   False
#
#                         Salary  Full Time  Part Time Date Posted
# 1592                       NaN      False      False  2022-01-20
# 1982   $5,157 - $7,596 a month      False      False  2022-01-20
# 2023                       NaN      False      False  2022-01-20
# 2049         $16 - $22 an hour      False      False  2022-01-20
# 2292         $17 - $24 an hour      False      False  2022-01-20
# ...                        ...        ...        ...         ...
# 840           From $15 an hour      False       True  2022-01-28
# 841   $40,000 - $60,000 a year       True      False  2022-01-28
# 843                        NaN       True      False  2022-01-28
# 847                $16 an hour       True      False  2022-01-28
# 852                        NaN       True      False  2022-01-28
#
# [140 rows x 8 columns]

# %%
# Remove duplicate job postings
total_job_posting_df.drop_duplicates(subset=['Job Title', 'Company Name', 'Location', 'Remote', 'Salary', 'Full Time', 'Part Time'],inplace=True, keep='last')
print(str(len(total_job_posting_df)) + " unique job postings")
# Out:
# 8046 unique job postings

# %%
# Save the new cumulative data set
total_job_posting_df.to_csv('../Data/Job_posting_data_cumulative.csv', index=False)

# %%
job_salaries = total_job_posting_df['Salary']
print(job_salaries)
# Out:
# 0                   $1,179 a week
# 1          $1,800 - $3,200 a week
# 2               $10 - $18 an hour
# 3      $100,000 - $150,000 a year
# 4      $100,000 - $175,000 a year
#                   ...
# 850                           NaN
# 851             $18 - $20 an hour
# 852                           NaN
# 853                           NaN
# 854                   $19 an hour
# Name: Salary, Length: 8046, dtype: object

# %%
total_job_posting_df['Salary Type'] = total_job_posting_df['Salary'].str.split().str[-1]
display(total_job_posting_df['Salary Type'].unique())
# Out:
# array(['week', 'hour', 'year', 'month', 'day', nan, 'mile', 'session'],
#       dtype=object)

# %%
# First, remove commas from Salary
total_job_posting_df['Salary'] = total_job_posting_df['Salary'].str.replace(',','')
print(total_job_posting_df)
# Out:
#                                              Job Title  \
# 0                           route sales representative
# 1                                ultrasound technician
# 2                     optometric ophthalmic technician
# 3                                           controller
# 4                                      account manager
# ..                                                 ...
# 850                                  warehouse manager
# 851                                    delivery driver
# 852  executive assistant administrative specialist ...
# 853                       nutritionist health educator
# 854        access control officer (part time)   savina
#
#                               Company Name  \
# 0                  frito lay north america
# 1                    proximity diagnostics
# 2                 imperial beach optometry
# 3                                 filtrous
# 4                            aya corporate
# ..                                     ...
# 850  behind the scenes catering and events
# 851                       le parfait paris
# 852                          woongjin, inc
# 853     family health centers of san diego
# 854             action property management
#
#                                               Location  Remote  \
# 0    San Diego, CA 92123 \n(Kearny Mesa area)\n+1 l...   False
# 1                                        San Diego, CA   False
# 2                Imperial Beach, CA 91932\n+1 location   False
# 3                                      Poway, CA 92064   False
# 4                         San Diego, CA\n+18 locations   False
# ..                                                 ...     ...
# 850                                      San Diego, CA   False
# 851                                San Diego, CA 92120   False
# 852                                      San Diego, CA   False
# 853  San Diego, CA 92102\n(Mt. Hope area)\n+1 location   False
# 854                  San Diego, CA 92101\n+3 locations   False
#
#                        Salary  Full Time  Part Time Date Posted Salary Type
# 0                $1179 a week       True      False    1/7/2022        week
# 1        $1800 - $3200 a week      False       True    1/7/2022        week
# 2           $10 - $18 an hour       True      False    1/7/2022        hour
# 3    $100000 - $150000 a year       True      False    1/7/2022        year
# 4    $100000 - $175000 a year      False      False    1/7/2022        year
# ..                        ...        ...        ...         ...         ...
# 850                       NaN       True      False  2022-01-28         NaN
# 851         $18 - $20 an hour      False       True  2022-01-28        hour
# 852                       NaN       True      False  2022-01-28         NaN
# 853                       NaN      False       True  2022-01-28         NaN
# 854               $19 an hour      False       True  2022-01-28        hour
#
# [8046 rows x 9 columns]

# %%
def get_salary_raw_number(row):
    # See if the salary data is a string
    if isinstance(row, str):
        # Find the word "Estimated"
        estimated = row.find("Estimated")
        if estimated != -1:
            # Find the raw number for salary $##.#K
            raw_number = re.search('(\d+(\.\d{1,2})?)K', row).group()
            raw_number = raw_number[:-1]
            raw_number = 1000 * float(raw_number)
        else:
            raw_number = re.search('(\d+)', row).group()
            raw_number = float(raw_number)
    else:
        return None
    return raw_number

# %%
# Get salary number to compute yearly salary

total_job_posting_df['Salary (Raw Number)'] = total_job_posting_df['Salary'].apply(lambda x: get_salary_raw_number(x))
print(total_job_posting_df)
# Out:
#                                              Job Title  \
# 0                           route sales representative
# 1                                ultrasound technician
# 2                     optometric ophthalmic technician
# 3                                           controller
# 4                                      account manager
# ..                                                 ...
# 850                                  warehouse manager
# 851                                    delivery driver
# 852  executive assistant administrative specialist ...
# 853                       nutritionist health educator
# 854        access control officer (part time)   savina
#
#                               Company Name  \
# 0                  frito lay north america
# 1                    proximity diagnostics
# 2                 imperial beach optometry
# 3                                 filtrous
# 4                            aya corporate
# ..                                     ...
# 850  behind the scenes catering and events
# 851                       le parfait paris
# 852                          woongjin, inc
# 853     family health centers of san diego
# 854             action property management
#
#                                               Location  Remote  \
# 0    San Diego, CA 92123 \n(Kearny Mesa area)\n+1 l...   False
# 1                                        San Diego, CA   False
# 2                Imperial Beach, CA 91932\n+1 location   False
# 3                                      Poway, CA 92064   False
# 4                         San Diego, CA\n+18 locations   False
# ..                                                 ...     ...
# 850                                      San Diego, CA   False
# 851                                San Diego, CA 92120   False
# 852                                      San Diego, CA   False
# 853  San Diego, CA 92102\n(Mt. Hope area)\n+1 location   False
# 854                  San Diego, CA 92101\n+3 locations   False
#
#                        Salary  Full Time  Part Time Date Posted Salary Type  \
# 0                $1179 a week       True      False    1/7/2022        week
# 1        $1800 - $3200 a week      False       True    1/7/2022        week
# 2           $10 - $18 an hour       True      False    1/7/2022        hour
# 3    $100000 - $150000 a year       True      False    1/7/2022        year
# 4    $100000 - $175000 a year      False      False    1/7/2022        year
# ..                        ...        ...        ...         ...         ...
# 850                       NaN       True      False  2022-01-28         NaN
# 851         $18 - $20 an hour      False       True  2022-01-28        hour
# 852                       NaN       True      False  2022-01-28         NaN
# 853                       NaN      False       True  2022-01-28         NaN
# 854               $19 an hour      False       True  2022-01-28        hour
#
#      Salary (Raw Number)
# 0                 1179.0
# 1                 1800.0
# 2                   10.0
# 3               100000.0
# 4               100000.0
# ..                   ...
# 850                  NaN
# 851                 18.0
# 852                  NaN
# 853                  NaN
# 854                 19.0
#
# [8046 rows x 10 columns]

# %%
def compute_yearly_salary(x):
    yearly_salary = None
    if x['Salary Type'] == "hour":
        yearly_salary = 2087 * int(x['Salary (Raw Number)'])
    elif x['Salary Type'] == "day":
        yearly_salary = 261 * int(x['Salary (Raw Number)'])
    elif x['Salary Type'] == "week":
        yearly_salary = 52 * int(x['Salary (Raw Number)'])
    elif x['Salary Type'] == "month":
        yearly_salary = 12 * int(x['Salary (Raw Number)'])
    elif x['Salary Type'] == "year":
        yearly_salary = int(x['Salary (Raw Number)'])
    else:
        yearly_salary = None
    return yearly_salary

# %%
total_job_posting_df['Annual Salary'] = total_job_posting_df.apply(compute_yearly_salary, axis=1)

# TODO: Format the Annual Salary column to currency
#job_posting_df['Annual Salary'] = job_posting_df['Annual Salary'].format("$*:")
display(total_job_posting_df)
# Out:
#                                              Job Title  \
# 0                           route sales representative
# 1                                ultrasound technician
# 2                     optometric ophthalmic technician
# 3                                           controller
# 4                                      account manager
# ..                                                 ...
# 850                                  warehouse manager
# 851                                    delivery driver
# 852  executive assistant administrative specialist ...
# 853                       nutritionist health educator
# 854        access control officer (part time)   savina
#
#                               Company Name  \
# 0                  frito lay north america
# 1                    proximity diagnostics
# 2                 imperial beach optometry
# 3                                 filtrous
# 4                            aya corporate
# ..                                     ...
# 850  behind the scenes catering and events
# 851                       le parfait paris
# 852                          woongjin, inc
# 853     family health centers of san diego
# 854             action property management
#
#                                               Location  Remote  \
# 0    San Diego, CA 92123 \n(Kearny Mesa area)\n+1 l...   False
# 1                                        San Diego, CA   False
# 2                Imperial Beach, CA 91932\n+1 location   False
# 3                                      Poway, CA 92064   False
# 4                         San Diego, CA\n+18 locations   False
# ..                                                 ...     ...
# 850                                      San Diego, CA   False
# 851                                San Diego, CA 92120   False
# 852                                      San Diego, CA   False
# 853  San Diego, CA 92102\n(Mt. Hope area)\n+1 location   False
# 854                  San Diego, CA 92101\n+3 locations   False
#
#                        Salary  Full Time  Part Time Date Posted Salary Type  \
# 0                $1179 a week       True      False    1/7/2022        week
# 1        $1800 - $3200 a week      False       True    1/7/2022        week
# 2           $10 - $18 an hour       True      False    1/7/2022        hour
# 3    $100000 - $150000 a year       True      False    1/7/2022        year
# 4    $100000 - $175000 a year      False      False    1/7/2022        year
# ..                        ...        ...        ...         ...         ...
# 850                       NaN       True      False  2022-01-28         NaN
# 851         $18 - $20 an hour      False       True  2022-01-28        hour
# 852                       NaN       True      False  2022-01-28         NaN
# 853                       NaN      False       True  2022-01-28         NaN
# 854               $19 an hour      False       True  2022-01-28        hour
#
#      Salary (Raw Number)  Annual Salary
# 0                 1179.0        61308.0
# 1                 1800.0        93600.0
# 2                   10.0        20870.0
# 3               100000.0       100000.0
# 4               100000.0       100000.0
# ..                   ...            ...
# 850                  NaN            NaN
# 851                 18.0        37566.0
# 852                  NaN            NaN
# 853                  NaN            NaN
# 854                 19.0        39653.0
#
# [8046 rows x 11 columns]

# %%
# Drop the unneccessary column
total_job_posting_df.pop('Salary (Raw Number)')
# Out:
# 0        1179.0
# 1        1800.0
# 2          10.0
# 3      100000.0
# 4      100000.0
#          ...
# 850         NaN
# 851        18.0
# 852         NaN
# 853         NaN
# 854        19.0
# Name: Salary (Raw Number), Length: 8046, dtype: float64

# %%
# Save the .csv file
total_job_posting_df.to_csv('../Data/Job_Posting_Data_With_Annual_Salary.csv', index=False)
