# %%
import pandas as pd

# %%
# Show current data set
job_posting_df = pd.read_csv("../Data/Job_posting_data_combined_date_and_relevancy_made_in_Jan_7.csv")

print(job_posting_df)
# Out:
#                                               Job Title  \
# 0                            Route Sales Representative
# 1                                 Ultrasound Technician
# 2                      Optometric/Ophthalmic Technician
# 3                                            Controller
# 4                                       Account Manager
# ...                                                 ...
# 1900                        Technical Support Scientist
# 1901                Delivery Driver - Pharmacy Services
# 1902                      Environmental Services Worker
# 1903  Reimbursement Specialist I - Reimbursement Ser...
# 1904                       Testing Services Coordinator
#
#                             Company Name  \
# 0                Frito-Lay North America
# 1                  Proximity Diagnostics
# 2               Imperial Beach Optometry
# 3                               Filtrous
# 4                          Aya Corporate
# ...                                  ...
# 1900                          bioMérieux
# 1901                     Cardinal Health
# 1902                    Sharp Healthcare
# 1903  Rady Children's Hospital-San Diego
# 1904                 National University
#
#                                                Location  Remote  \
# 0     San Diego, CA 92123 \n(Kearny Mesa area)\n+1 l...   False
# 1                                         San Diego, CA   False
# 2                 Imperial Beach, CA 91932\n+1 location   False
# 3                                       Poway, CA 92064   False
# 4                          San Diego, CA\n+18 locations   False
# ...                                                 ...     ...
# 1900                                      San Diego, CA   False
# 1901                                San Diego, CA 92108   False
# 1902                                      San Diego, CA   False
# 1903                        San Diego, CA\n+4 locations   False
# 1904                                San Diego, CA 92106   False
#
#                           Salary  Full Time  Part Time Date Posted
# 0                  $1,179 a week       True      False    1/7/2022
# 1         $1,800 - $3,200 a week      False       True    1/7/2022
# 2              $10 - $18 an hour       True      False    1/7/2022
# 3     $100,000 - $150,000 a year       True      False    1/7/2022
# 4     $100,000 - $175,000 a year      False      False    1/7/2022
# ...                          ...        ...        ...         ...
# 1900                         NaN       True      False    1/4/2022
# 1901                         NaN       True      False  12/30/2021
# 1902                         NaN      False      False  12/29/2021
# 1903                         NaN       True      False  12/31/2021
# 1904                         NaN       True      False  12/16/2021
#
# [1905 rows x 8 columns]

# %% [markdown]
# # Here, we remove the duplicate rows, (ignoring the "Date Posted" b/c the same job can be posted on multiple days)

# %%
#Find duplicate job postings
job_posting_df.loc[job_posting_df.duplicated(subset=['Job Title', 'Company Name', 'Location', 'Remote', 'Salary'])]
# Out:
#                                        Job Title  \
# 15        Forensic Toxicology Laboratory Manager
# 70    Diaper Bank Support Specialist - Temporary
# 71    Diaper Bank Support Specialist - Temporary
# 91                    Traffic Control Technician
# 106              Data Center Solutions Architect
# ...                                          ...
# 1865   Specimen Handler / Accessioner Contractor
# 1866   Specimen Handler / Accessioner Contractor
# 1869                     Sterile Processing Tech
# 1870               Program Management Specialist
# 1873     Shipping and Receiving Associate II 1 1
#
#                             Company Name  \
# 15                   County of San Diego
# 70    Jewish Family Service of San Diego
# 71    Jewish Family Service of San Diego
# 91            West Coast Traffic Control
# 106                          CyberCoders
# ...                                  ...
# 1865                               Helix
# 1866                               Helix
# 1869            Allcare Nursing Services
# 1870              INDUS Technology, Inc.
# 1873                             Grifols
#
#                                         Location  Remote  \
# 15          San Diego, CA \n(Core-Columbia area)   False
# 70      San Diego, CA 92123 \n(Kearny Mesa area)   False
# 71      San Diego, CA 92123 \n(Kearny Mesa area)   False
# 91                    San Diego, CA\n+1 location   False
# 106            San Diego, CA 92123\n+2 locations   False
# ...                                          ...     ...
# 1865                               San Diego, CA   False
# 1866  San Diego, CA 92113 \n(Logan Heights area)   False
# 1869                               San Diego, CA   False
# 1870       San Diego, CA 92110 \n(Old Town area)   False
# 1873                         San Diego, CA 92102   False
#
#                           Salary  Full Time  Part Time Date Posted
# 15    $120,000 - $130,000 a year       True      False    1/7/2022
# 70             $16 - $17 an hour      False      False    1/7/2022
# 71             $16 - $17 an hour      False      False    1/7/2022
# 91             $16 - $30 an hour       True      False    1/7/2022
# 106   $160,000 - $215,000 a year       True      False    1/7/2022
# ...                          ...        ...        ...         ...
# 1865                         NaN      False      False    1/7/2022
# 1866                         NaN      False      False    1/7/2022
# 1869                         NaN      False      False   12/8/2021
# 1870                         NaN       True      False    1/7/2022
# 1873                         NaN       True      False   12/8/2021
#
# [330 rows x 8 columns]

# %%
job_posting_df.drop_duplicates(subset=['Job Title', 'Company Name', 'Location', 'Remote', 'Salary', 'Full Time', 'Part Time'],inplace=True, keep='first')
print(str(len(job_posting_df)) + " unique job postings")
# Out:
# 1575 unique job postings

# %%
job_salaries = job_posting_df['Salary']
print(job_salaries)
# Out:
# 0                    $1,179 a week
# 1           $1,800 - $3,200 a week
# 2                $10 - $18 an hour
# 3       $100,000 - $150,000 a year
# 4       $100,000 - $175,000 a year
#                    ...
# 1900                           NaN
# 1901                           NaN
# 1902                           NaN
# 1903                           NaN
# 1904                           NaN
# Name: Salary, Length: 1575, dtype: object

# %%
job_posting_df['Salary Type'] = job_posting_df['Salary'].str.split().str[-1]
display(job_posting_df['Salary Type'].unique())
# Out:
# array(['week', 'hour', 'year', 'month', 'day', nan], dtype=object)

# %%
# First, remove commas from Salary
job_posting_df['Salary'] = job_posting_df['Salary'].str.replace(',','')
print(job_posting_df)
# Out:
#                                               Job Title  \
# 0                            Route Sales Representative
# 1                                 Ultrasound Technician
# 2                      Optometric/Ophthalmic Technician
# 3                                            Controller
# 4                                       Account Manager
# ...                                                 ...
# 1900                        Technical Support Scientist
# 1901                Delivery Driver - Pharmacy Services
# 1902                      Environmental Services Worker
# 1903  Reimbursement Specialist I - Reimbursement Ser...
# 1904                       Testing Services Coordinator
#
#                             Company Name  \
# 0                Frito-Lay North America
# 1                  Proximity Diagnostics
# 2               Imperial Beach Optometry
# 3                               Filtrous
# 4                          Aya Corporate
# ...                                  ...
# 1900                          bioMérieux
# 1901                     Cardinal Health
# 1902                    Sharp Healthcare
# 1903  Rady Children's Hospital-San Diego
# 1904                 National University
#
#                                                Location  Remote  \
# 0     San Diego, CA 92123 \n(Kearny Mesa area)\n+1 l...   False
# 1                                         San Diego, CA   False
# 2                 Imperial Beach, CA 91932\n+1 location   False
# 3                                       Poway, CA 92064   False
# 4                          San Diego, CA\n+18 locations   False
# ...                                                 ...     ...
# 1900                                      San Diego, CA   False
# 1901                                San Diego, CA 92108   False
# 1902                                      San Diego, CA   False
# 1903                        San Diego, CA\n+4 locations   False
# 1904                                San Diego, CA 92106   False
#
#                         Salary  Full Time  Part Time Date Posted Salary Type
# 0                 $1179 a week       True      False    1/7/2022        week
# 1         $1800 - $3200 a week      False       True    1/7/2022        week
# 2            $10 - $18 an hour       True      False    1/7/2022        hour
# 3     $100000 - $150000 a year       True      False    1/7/2022        year
# 4     $100000 - $175000 a year      False      False    1/7/2022        year
# ...                        ...        ...        ...         ...         ...
# 1900                       NaN       True      False    1/4/2022         NaN
# 1901                       NaN       True      False  12/30/2021         NaN
# 1902                       NaN      False      False  12/29/2021         NaN
# 1903                       NaN       True      False  12/31/2021         NaN
# 1904                       NaN       True      False  12/16/2021         NaN
#
# [1575 rows x 9 columns]

# %%
# Get salary number to compute yearly salary

job_posting_df['Salary (Raw Number)'] = job_posting_df['Salary'].str.extract('(\d+)')
print(job_posting_df)
# Out:
#                                               Job Title  \
# 0                            Route Sales Representative
# 1                                 Ultrasound Technician
# 2                      Optometric/Ophthalmic Technician
# 3                                            Controller
# 4                                       Account Manager
# ...                                                 ...
# 1900                        Technical Support Scientist
# 1901                Delivery Driver - Pharmacy Services
# 1902                      Environmental Services Worker
# 1903  Reimbursement Specialist I - Reimbursement Ser...
# 1904                       Testing Services Coordinator
#
#                             Company Name  \
# 0                Frito-Lay North America
# 1                  Proximity Diagnostics
# 2               Imperial Beach Optometry
# 3                               Filtrous
# 4                          Aya Corporate
# ...                                  ...
# 1900                          bioMérieux
# 1901                     Cardinal Health
# 1902                    Sharp Healthcare
# 1903  Rady Children's Hospital-San Diego
# 1904                 National University
#
#                                                Location  Remote  \
# 0     San Diego, CA 92123 \n(Kearny Mesa area)\n+1 l...   False
# 1                                         San Diego, CA   False
# 2                 Imperial Beach, CA 91932\n+1 location   False
# 3                                       Poway, CA 92064   False
# 4                          San Diego, CA\n+18 locations   False
# ...                                                 ...     ...
# 1900                                      San Diego, CA   False
# 1901                                San Diego, CA 92108   False
# 1902                                      San Diego, CA   False
# 1903                        San Diego, CA\n+4 locations   False
# 1904                                San Diego, CA 92106   False
#
#                         Salary  Full Time  Part Time Date Posted Salary Type  \
# 0                 $1179 a week       True      False    1/7/2022        week
# 1         $1800 - $3200 a week      False       True    1/7/2022        week
# 2            $10 - $18 an hour       True      False    1/7/2022        hour
# 3     $100000 - $150000 a year       True      False    1/7/2022        year
# 4     $100000 - $175000 a year      False      False    1/7/2022        year
# ...                        ...        ...        ...         ...         ...
# 1900                       NaN       True      False    1/4/2022         NaN
# 1901                       NaN       True      False  12/30/2021         NaN
# 1902                       NaN      False      False  12/29/2021         NaN
# 1903                       NaN       True      False  12/31/2021         NaN
# 1904                       NaN       True      False  12/16/2021         NaN
#
#      Salary (Raw Number)
# 0                   1179
# 1                   1800
# 2                     10
# 3                 100000
# 4                 100000
# ...                  ...
# 1900                 NaN
# 1901                 NaN
# 1902                 NaN
# 1903                 NaN
# 1904                 NaN
#
# [1575 rows x 10 columns]

# %%
def compute_yearly_salary(x):
    yearly_salary = None
    if x['Salary Type'] == "hour":
        yearly_salary = 2087 * int(x['Salary (Raw Number)'])
    elif x['Salary Type'] == "day":
        yearly_salary = 261 * int(x['Salary (Raw Number)'])
    elif x['Salary Type'] == "week":
        yearly_salary = 52 * int(x['Salary (Raw Number)'])
    elif x['Salary Type'] == "month":
        yearly_salary = 12 * int(x['Salary (Raw Number)'])
    elif x['Salary Type'] == "year":
        yearly_salary = int(x['Salary (Raw Number)'])
    else:
        yearly_salary = None
    return yearly_salary

# %%
job_posting_df['Annual Salary'] = job_posting_df.apply(compute_yearly_salary, axis=1)

# TODO: Format the Annual Salary column to currency
#job_posting_df['Annual Salary'] = job_posting_df['Annual Salary'].format("$*:")
display(job_posting_df)
# Out:
#                                               Job Title  \
# 0                            Route Sales Representative
# 1                                 Ultrasound Technician
# 2                      Optometric/Ophthalmic Technician
# 3                                            Controller
# 4                                       Account Manager
# ...                                                 ...
# 1900                        Technical Support Scientist
# 1901                Delivery Driver - Pharmacy Services
# 1902                      Environmental Services Worker
# 1903  Reimbursement Specialist I - Reimbursement Ser...
# 1904                       Testing Services Coordinator
#
#                             Company Name  \
# 0                Frito-Lay North America
# 1                  Proximity Diagnostics
# 2               Imperial Beach Optometry
# 3                               Filtrous
# 4                          Aya Corporate
# ...                                  ...
# 1900                          bioMérieux
# 1901                     Cardinal Health
# 1902                    Sharp Healthcare
# 1903  Rady Children's Hospital-San Diego
# 1904                 National University
#
#                                                Location  Remote  \
# 0     San Diego, CA 92123 \n(Kearny Mesa area)\n+1 l...   False
# 1                                         San Diego, CA   False
# 2                 Imperial Beach, CA 91932\n+1 location   False
# 3                                       Poway, CA 92064   False
# 4                          San Diego, CA\n+18 locations   False
# ...                                                 ...     ...
# 1900                                      San Diego, CA   False
# 1901                                San Diego, CA 92108   False
# 1902                                      San Diego, CA   False
# 1903                        San Diego, CA\n+4 locations   False
# 1904                                San Diego, CA 92106   False
#
#                         Salary  Full Time  Part Time Date Posted Salary Type  \
# 0                 $1179 a week       True      False    1/7/2022        week
# 1         $1800 - $3200 a week      False       True    1/7/2022        week
# 2            $10 - $18 an hour       True      False    1/7/2022        hour
# 3     $100000 - $150000 a year       True      False    1/7/2022        year
# 4     $100000 - $175000 a year      False      False    1/7/2022        year
# ...                        ...        ...        ...         ...         ...
# 1900                       NaN       True      False    1/4/2022         NaN
# 1901                       NaN       True      False  12/30/2021         NaN
# 1902                       NaN      False      False  12/29/2021         NaN
# 1903                       NaN       True      False  12/31/2021         NaN
# 1904                       NaN       True      False  12/16/2021         NaN
#
#      Salary (Raw Number)  Annual Salary
# 0                   1179        61308.0
# 1                   1800        93600.0
# 2                     10        20870.0
# 3                 100000       100000.0
# 4                 100000       100000.0
# ...                  ...            ...
# 1900                 NaN            NaN
# 1901                 NaN            NaN
# 1902                 NaN            NaN
# 1903                 NaN            NaN
# 1904                 NaN            NaN
#
# [1575 rows x 11 columns]

# %%
# Drop the unneccessary column
job_posting_df.pop('Salary (Raw Number)')
# Out:
# 0         1179
# 1         1800
# 2           10
# 3       100000
# 4       100000
#          ...
# 1900       NaN
# 1901       NaN
# 1902       NaN
# 1903       NaN
# 1904       NaN
# Name: Salary (Raw Number), Length: 1575, dtype: object

# %%
# Save the .csv file
job_posting_df.to_csv('../Data/Job_Posting_Data_With_Annual_Salary.csv', index=False)
